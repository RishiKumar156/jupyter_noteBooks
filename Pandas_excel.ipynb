# %%
import pandas as pd 
df = pd.read_csv("video_games_sales.csv")
df
# Out:
#       index,Name Platform Year_of_Release Genre  Publisher  NA_Sales EU_Sales  \
# 0           0,53       76              51     8      322.0  Nintendo        E
# 1           1,24      NaN             NaN   NaN        NaN       NaN      NaN
# 2           2,77       80              73     8      192.0  Nintendo        E
# 3             3,      NaN             NaN   NaN        NaN       NaN      NaN
# 4           4,26      NaN             NaN   NaN        NaN       NaN      NaN
# ...          ...      ...             ...   ...        ...       ...      ...
# 14992     14992,      NaN             NaN   NaN        NaN       NaN      NaN
# 14993     14993,      NaN             NaN   NaN        NaN       NaN      NaN
# 14994     14994,      NaN             NaN   NaN        NaN       NaN      NaN
# 14995     14995,      NaN             NaN   NaN        NaN       NaN      NaN
# 14996     14996,      NaN             NaN   NaN        NaN       NaN      NaN
#
# ...
