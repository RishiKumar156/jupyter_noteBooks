# %%
import pandas as pd 
df = pd.read_csv("BooksDataSet.csv", index_col=False)
df['Authors'] = df['Authors'].str.replace("By", '')
df['Price'] = df['Price'].str.replace("Price Starting at", '')
# Clean up the 'Publish Date' column using regex
days_to_remove = ["Friday", "Saturday", "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday"]
days_pattern = '|'.join(days_to_remove)
"""so here we are going to split the data with months and years """
df['Publish Date'] = df['Publish Date'].str.replace(f'({days_pattern}),', '', regex=True)
df['Publish Date'] = pd.to_datetime(df['Publish Date'],errors='coerce')
df['moths'] = df['Publish Date'].dt.month
df['years'] = df['Publish Date'].dt.year
df = df.drop_duplicates()
df
# Out:
#                                                     Title  \
# 0                                           Goat Brothers
# 1                                      The Missing Person
# 2                       Don't Eat Your Heart Out Cookbook
# 3       When Your Corporate Umbrella Begins to Leak: A...
# 4         Amy Spangler's Breastfeeding : A Parent's Guide
# ...                                                   ...
# 103077                        Build 3 Super Serving Carts
# 103078                                  My Land of Israel
# 103079                  Tongues: To Speak or Not to Speak
# 103080   If I'm in charge here why is everybody laughing?
# 103081               Your First Puppy (Your First Series)
#
#                        Authors  \
# 0                Colton, Larry
# 1              Grumbach, Doris
# 2        Piscatella, Joseph C.
# 3               Davis, Paul D.
# 4                Spangler, Amy
# ...                        ...
# 103077           Chuck Hampton
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index,Name       10 non-null     object
#  1   Platform         4 non-null      float64
#  2   Year_of_Release  4 non-null      object
#  3   Genre            4 non-null      object
#  4   Publisher        3 non-null      float64
#  5   NA_Sales         3 non-null      object
#  6   EU_Sales         3 non-null      object
#  7   JP_Sales         0 non-null      float64
#  8   Other_Sales      0 non-null      float64
#  9   Global_Sales     0 non-null      float64
#  10  Critic_Score     0 non-null      float64
#  11  Critic_Count     0 non-null      float64
#  12  User_Score       0 non-null      float64
#  13  User_Count       0 non-null      float64
#  14  Developer        0 non-null      float64
#  15  Rating           0 non-null      float64
# ...

# %%
df.describe()
# Out:
#                  Title Authors  \
# count           103082  103082
# unique           97818   63580
# top     The Nutcracker
# freq                12    1043
#
#                                               Description            Category  \
# count                                               70213               76912
# unique                                              68831                3106
# top     For Ingest Only - Data needs to be cleaned up ...   Fiction , General
# freq                                                   30                2549
#
#                Publisher               Publish Date                    Price
# count             103074                     103082                   103082
# unique             13029                        956                     1387
# top     Simon & Schuster  Thursday, January 1, 2004  Price Starting at $5.29
# freq                1521                        868                    41876

# %%
pd.set_option('display.float_format' , lambda x: '%.2f' % x)

# %%
df.describe() #some test sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.describe() #some test sample
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum() #this isnull used to find the null data and .sum() used to find the some of the null data
# Out:
# index,Name          0
# Platform            6
# Year_of_Release     6
# Genre               6
# Publisher           7
# NA_Sales            7
# EU_Sales            7
# JP_Sales           10
# Other_Sales        10
# Global_Sales       10
# Critic_Score       10
# Critic_Count       10
# User_Score         10
# User_Count         10
# Developer          10
# Rating             10
# Unnamed: 16        10
# Unnamed: 17        10
# dtype: int64

# %%
df.nunique() #this will find the unique values
# Out:
# index,Name         10
# Platform            4
# Year_of_Release     4
# Genre               3
# Publisher           3
# NA_Sales            2
# EU_Sales            2
# JP_Sales            0
# Other_Sales         0
# Global_Sales        0
# Critic_Score        0
# Critic_Count        0
# User_Score          0
# User_Count          0
# Developer           0
# Rating              0
# Unnamed: 16         0
# Unnamed: 17         0
# dtype: int64

# %%
df.sort_values(by="Publish Date")  #sort based on the column name
# Out:
#                                                    Title  \
# 40126                                American Wonderland
# 7041                        House Beautiful Entertaining
# 55623                       The Wood Finisher's Handbook
# 2375             Complete Book of Birdhouses and Feeders
# 415                     500 Full-Size Patchwork Patterns
# ...                                                  ...
# 87499  Hope Unseen: The Story of the U.S. Army's Firs...
# 89956                       The Seventeen Second Miracle
# 87495  Big Girls Don't Cry: The Election that Changed...
# 87410  Bloody Crimes: The Chase for Jefferson Davis a...
# 87474                                   Immanuel's Veins
#
#                                                  Authors  \
# 40126                               Bache, Richard Meade
# 7041    Gropp, Louis Oliver (EDT), Kennedy, Margaret ...
# 55623                                         Allen, Sam
# ...

# %%
df.sort_values(by="Publish Date",ascending=True) #sort based on the column and head will just get the top once
# Out:
#                                                    Title  \
# 40126                                American Wonderland
# 7041                        House Beautiful Entertaining
# 55623                       The Wood Finisher's Handbook
# 2375             Complete Book of Birdhouses and Feeders
# 415                     500 Full-Size Patchwork Patterns
# ...                                                  ...
# 87499  Hope Unseen: The Story of the U.S. Army's Firs...
# 89956                       The Seventeen Second Miracle
# 87495  Big Girls Don't Cry: The Election that Changed...
# 87410  Bloody Crimes: The Chase for Jefferson Davis a...
# 87474                                   Immanuel's Veins
#
#                                                  Authors  \
# 40126                               Bache, Richard Meade
# 7041    Gropp, Louis Oliver (EDT), Kennedy, Margaret ...
# 55623                                         Allen, Sam
# ...

# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 2.1.4

# %%
#search inside the cleaned data sets 
import pandas as pd
df = pd.read_csv('BooksDatasetClean.csv')
df
# Out:
#                                                     Title  \
# 0                                           Goat Brothers
# 1                                      The Missing Person
# 2                       Don't Eat Your Heart Out Cookbook
# 3       When Your Corporate Umbrella Begins to Leak: A...
# 4         Amy Spangler's Breastfeeding : A Parent's Guide
# ...                                                   ...
# 103058                        Build 3 Super Serving Carts
# 103059                                  My Land of Israel
# 103060                  Tongues: To Speak or Not to Speak
# 103061   If I'm in charge here why is everybody laughing?
# 103062               Your First Puppy (Your First Series)
#
#                          Authors  \
# 0               By Colton, Larry
# 1             By Grumbach, Doris
# 2       By Piscatella, Joseph C.
# 3              By Davis, Paul D.
# 4               By Spangler, Amy
# ...                          ...
# ...
